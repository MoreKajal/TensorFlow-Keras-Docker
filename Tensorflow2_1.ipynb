# %% [markdown]
# <a href="https://colab.research.google.com/github/MoreKajal/TensorFlow-Keras-Docker/blob/Tensorflow/Tensorflow2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hello to TensorFlow 2.0

# %% [markdown]
# #Hello Colab!

# %%
#Mount drive
from google.colab import drive
drive.mount('gdrive')
# Out:
# Mounted at gdrive

# %%
#Use open function to open a file

myfile = open('/content/gdrive/MyDrive/TensorFlow/Tensorflow2.ipynb')
print(myfile.read())
# Out:
# {"nbformat":4,"nbformat_minor":0,"metadata":{"colab":{"name":"Tensorflow2.ipynb","provenance":[],"authorship_tag":"ABX9TyNi7H6Fc/23ZgFzY6XDvkwh"},"kernelspec":{"name":"python3","display_name":"Python 3"},"language_info":{"name":"python"}},"cells":[{"cell_type":"markdown","metadata":{"id":"MO55c8Krmppi"},"source":["\n","Hello to TensorFlow 2.0\n"]},{"cell_type":"code","metadata":{"id":"NuVJMxjZqkfG"},"source":[""],"execution_count":null,"outputs":[]},{"cell_type":"markdown","metadata":{"id":"ULM0RFeJpxJH"},"source":["#Hello Colab!"]},{"cell_type":"code","metadata":{"colab":{"base_uri":"https://localhost:8080/"},"id":"pwZzJVTKpkzI","executionInfo":{"status":"ok","timestamp":1635252814413,"user_tz":-330,"elapsed":40048,"user":{"displayName":"KAJAL RAMESH MORE","photoUrl":"https://lh3.googleusercontent.com/a-/AOh14Gi9gaE22AwwdzTDUlaXoqjmcem8-rGh9MjZ3Md9=s64","userId":"08181983420396721215"}},"outputId":"db1c5b32-19ce-460e-d8be-6ca5a0009fa5"},"source":["#Mount drive\n","from google.colab 
# ...

# %% [markdown]
# #Use of Bash commands
# - Prepend the command with !
# - We can use Bassh commands to install any packages

# %%
# !ls
# Out:
# gdrive	sample_data

# %%
# !pip install numpy

# %%
# !pip install tensorflow==2
# Out:
# ...
#      |████████████████████████████████| 86.3 MB 18 kB/s
# ...
#      |████████████████████████████████| 3.8 MB 48.4 MB/s
# ...
#      |████████████████████████████████| 50 kB 3.3 MB/s
# ...
#      |████████████████████████████████| 449 kB 47.0 MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7554 sha256=fd76e64d0cbc120e21a8498afb116333ed9534391405760b99582a2e0ed75047
#   Stored in directory: /root/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
# Successfully built gast
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.6.0
#     Uninstalling tensorflow-estimator-2.6.0:
#       Successfully uninstalled tensorflow-estimator-2.6.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.6.0
#     Uninstalling tensorboard-2.6.0:
#       Successfully uninstalled tensorboard-2.6.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.4.0
# ...

# %%
#Restart runtime and check Import version 

import tensorflow as tf

tf.__version__
# Out:
# '2.0.0'

# %% [markdown]
# #Some steps to be followed while installing tensorflow cpu version
#
# pip --version    #T0 check pip version (19.0 or above)
#
# python3 --version
#
# -Download and install virtual environment by
#
# pip install --user -U virtualenv
#
# -Create a virtual env that uses python 3
#
# virtualenv name_of_env  (eg : virtualenv TF2env)
#
# -To iteralte to a newly created environment
#
# source name_of_env/bin/activate
#
# -(We can see the env is activated by the paranthesis (TF2env) expression in the terminal)
#
# -Now we can install tensorflow2 in the environment
#
# pip install tensorflow==2.0
#
# -Once the download and install is completed, open Python3 to verify TF version
#
# python 3
#
# import tensorflow as tf
#
# tf.__version__

# %% [markdown]
# #Why to use Virtual environments
#
# -Virtual environment allows you to neatly maintain multiple versions of single package or even of Python on your machine

# %% [markdown]
# #How to upgrade TF1 to TF2
#
# -Some times we get the error like tensorflow version is not compatible(tensorflow has no attribute 'placeholder')
#
# tf_upgrade_v2 --infile name_of_file.py --outfile rename_the_file.py
#
# -You will get a log file(.txt or log) to understand the changes took placed.
#
# vi log_file_name    (To open the file in the terminal)
#
# -If you try to run the upgraded script with TF2, it will fail to run
# (Runtime error : tf.placeholder() is not compatible with eager execution )
# This is beacuse the code relies on Graph and session type execution
#
# -Therefore to disable eager execution upgrade the file_tf2.py by adding a line after import statements
#
# tf.compat.v1.disable_eager_execution()
